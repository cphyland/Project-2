# %%
import os
import sys
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
from sqlalchemy.exc import SQLAlchemyError
import matplotlib.pyplot as plt
import csv

# %%
SharkData = pd.read_csv('https://raw.githubusercontent.com/cphyland/Project-2/main/data/sharks/shark_sightings_raw.csv',index_col=False)
SharkData.head()
df = SharkData
df.head()
# Out:
#    Unnamed: 0  RawDataId    ObjectId  Distance DistanceUnit InteractionValue  \
# 0           0      63739        3073       NaN          NaN         Detected
# 1           1      63738        3073       NaN          NaN         Detected
# 2           2      63737        3073       NaN          NaN         Detected
# 3           3      63736  WA12582TSE      50.0   m offshore          sighted
# 4           4      63735  WA51495TSE     600.0   m offshore          sighted
#
#    InteractionId TownProximity                    LocationValue  \
# 0              4           NaN                           Meelup
# 1              4           NaN                           Meelup
# 2              4           NaN                           Meelup
# 3              1   Perth Metro  Jervoise Bay Beach, Perth Metro
# 4              1     Coral Bay      Bateman Bay, near Coral Bay
#
#   SightingNumbervalue ReportDateTime     SightingDateTime SightingSizeValue  \
# ...

# %%
df = df[(df['SightingDateTime'] > '2020-01-01T02:03:00') & (df['SightingDateTime'] <= '2021-07-24T17:48:00')]

# %%
df.head()
# Out:
#    Unnamed: 0  RawDataId    ObjectId  Distance DistanceUnit InteractionValue  \
# 0           0      63739        3073       NaN          NaN         Detected
# 1           1      63738        3073       NaN          NaN         Detected
# 2           2      63737        3073       NaN          NaN         Detected
# 3           3      63736  WA12582TSE      50.0   m offshore          sighted
# 4           4      63735  WA51495TSE     600.0   m offshore          sighted
#
#    InteractionId TownProximity                    LocationValue  \
# 0              4           NaN                           Meelup
# 1              4           NaN                           Meelup
# 2              4           NaN                           Meelup
# 3              1   Perth Metro  Jervoise Bay Beach, Perth Metro
# 4              1     Coral Bay      Bateman Bay, near Coral Bay
#
#   SightingNumbervalue ReportDateTime     SightingDateTime SightingSizeValue  \
# ...

# %%
df.to_csv("clean_shark_data.csv")
